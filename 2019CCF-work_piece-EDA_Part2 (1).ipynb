# %%
import pandas as pd
pd.set_option('display.max_column',30)
import numpy as np
import statsmodels.api as sm
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

from pylab import rcParams ##matplotlib
rcParams['figure.figsize'] = 12, 8

import warnings 
warnings.filterwarnings('ignore')

from pyecharts import options as opts
from pyecharts.charts import Bar, Line, Pie, Map, Page, ThemeRiver, Timeline, Grid
from pyecharts.commons.utils import JsCode

# %%
train = pd.read_csv('./first_round_training_data.csv')[['Parameter'+str(i) for i in range(1,11)]+['Quality_label']].round(5)
test = pd.read_csv('./first_round_testing_data.csv').round(5)
feature = ['Parameter'+str(i) for i in range(1,11)]

# %%
print(train.head())
# Out:
#    Parameter1  Parameter2  Parameter3  Parameter4  Parameter5  Parameter6  \
# 0     0.00166     0.59101   147.60837    38.18634     0.00042     0.00061
# 1     1.60175     0.01505     0.03586    51.13033     0.00091     0.00240
# 2     0.09804    69.23368     0.08092     0.11227     0.00091     0.00197
# 3    18.18186     0.04733     0.01806     1.09810     0.00091     0.00240
# 4     0.01209     0.00875     0.00551   524.32740     0.00091     0.00240
#
#    Parameter7  Parameter8  Parameter9  Parameter10 Quality_label
# 0  2286.52341     0.03541     0.59308      1.01038          Pass
# 1  2286.52341     0.03541     0.59308      1.01038          Fail
# 2  2286.52341     0.03541     0.59308      1.01038          Fail
# 3  2286.52341     0.03541     0.59308      1.01038          Fail
# 4  2286.52341     0.03541     0.59308      1.01038          Fail

# %% [markdown]
# 了解数据分布

# %%
print(train.describe())
# Out:
#           Parameter1    Parameter2     Parameter3     Parameter4   Parameter5  \
# count    6000.000000  6.000000e+03    6000.000000    6000.000000  6000.000000
# mean      485.198954  1.952379e+03     406.348529     189.205842     5.868163
# std     11401.971393  5.419588e+04   12018.898941    2621.779049     8.631865
# min         0.000000  0.000000e+00       0.000010       0.000000     0.000000
# 25%         0.088222  4.766000e-02       0.102300       0.118315     0.741630
# 50%         1.050300  9.405950e-01       1.044910       1.068470     2.225810
# 75%        10.938570  1.569199e+01      10.665400       9.902065     6.680180
# max    713682.207600  3.034568e+06  864530.632180  139767.494730    83.671950
#
#         Parameter6    Parameter7    Parameter8    Parameter9  Parameter10
# count  6000.000000   6000.000000   6000.000000  6.000000e+03  6000.000000
# mean      5.598597    272.300821     22.133232  5.823664e+04    35.902067
# std       7.686898   2027.460513    302.172767  3.173068e+06   101.629347
# min       0.000000      0.000620      0.023700  4.000000e-04     0.001020
# 25%       0.381820      0.152060      0.035410  5.930800e-01     0.101480
# 50%       2.684400      0.600830      2.931080  5.930800e-01     0.727610
# 75%       7.117770      2.374030     17.850020  6.783970e+00    13.969790
# max      41.175410  35698.591550  20086.397750  1.738083e+08   517.197610

# %% [markdown]
# 找出数值变量和类别变量

# %%
print(train.nunique())
# print(test_x1.nunique())
# Out:
# Parameter1       5758
# Parameter2       5514
# Parameter3       5779
# Parameter4       5802
# Parameter5        126
# Parameter6         74
# Parameter7         14
# Parameter8         23
# Parameter9         16
# Parameter10        41
# Quality_label       4
# dtype: int64

# %% [markdown]
# 从上可以看出，参数5到参数10都是类别变量（离散型变量，下面探究离散型变量和Quality_label之间的关系）

# %% [markdown]
# ## `Parameter` 与 `label` 分布情况

# %% [markdown]
# 离散型数据变量和目标之间的可视化

# %%
def parameter_label(data, title, max_) -> Bar:
    data = data.sort_values(title, ascending=True)
    c = (
        Bar()
        .add_xaxis(sorted(list(set(data[title]))))
        .add_yaxis("Excellent", list(data[data['Quality_label']=='Excellent']['count']), stack="stack1")
        .add_yaxis("Good", list(data[data['Quality_label']=='Good']['count']), stack="stack1")
        .add_yaxis("Pass", list(data[data['Quality_label']=='Pass']['count']), stack="stack1")
        .add_yaxis("Fail", list(data[data['Quality_label']=='Fail']['count']), stack="stack1")
        .set_series_opts(label_opts=opts.LabelOpts(is_show=False))
        .set_global_opts(
            title_opts=opts.TitleOpts(title=title,subtitle='https://lambda-xmu.club'),
            toolbox_opts=opts.ToolboxOpts(),
            yaxis_opts=opts.AxisOpts(
                max_= max_,
            ),
        )
    )
    return c

# %%
data = train.groupby(['Parameter5','Quality_label'],as_index=False)['Parameter1'].count().rename(
    columns={'Parameter1':'count'})

c = parameter_label(data, 'Parameter5', 180)
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="2b58a1033bd148c69ca8aa4e33559c22" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_2b58a1033bd148c69ca8aa4e33559c22 = echarts.init(
#                     document.getElementById('2b58a1033bd148c69ca8aa4e33559c22'), 'white', {renderer: 'canvas'});
#                 var option_2b58a1033bd148c69ca8aa4e33559c22 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "name": "Excellent",
#             "data": [
#                 1,
#                 6,
#                 1,
#                 2,
#                 3,
#                 1,
#                 3,
#                 12,
#                 9,
#                 10,
#                 4,
#                 3,
#                 3,
#                 3,
#                 7,
#                 6,
#                 1,
#                 1,
#                 3,
#                 2,
#                 2,
#                 3,
#                 2,
#                 8,
#                 8,
#                 6,
#                 3,
#                 3,
#                 1,
#                 1,
#                 1,
#                 5,
#                 1,
#                 2,
#                 1,
#                 5,
#                 1,
#                 1,
#                 1,
#                 7,
#                 6,
#                 3,
#                 1,
#                 1,
#                 4,
#                 4,
#                 17,
#                 11,
#                 12,
#                 16,
#                 22,
#                 47,
#                 38,
#                 41,
#                 62,
#                 26,
#                 38,
#                 27,
#                 24,
#                 48,
#                 19,
#                 29,
#                 28,
#                 45,
#                 43,
#                 14,
#                 39,
#                 23,
#                 19,
#                 51,
#                 39,
#                 24,
#                 30,
#                 7,
#                 11,
#                 8,
#                 9,
#                 14,
#                 5,
#                 2,
#                 6,
#                 10,
#                 20,
#                 6,
#                 5,
#                 4,
#                 3,
#                 2,
#                 1
#             ],
#             "stack": "stack1",
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         },
#         {
#             "type": "bar",
#             "name": "Good",
#             "data": [
#                 2,
#                 3,
#                 3,
#                 3,
#                 1,
#                 7,
#                 4,
#                 2,
#                 5,
#                 7,
#                 1,
#                 2,
#                 4,
#                 7,
#                 19,
#                 24,
#                 1,
#                 2,
#                 13,
#                 10,
#                 14,
#                 1,
#                 4,
#                 7,
#                 8,
#                 2,
#                 6,
#                 11,
#                 6,
#                 7,
#                 2,
#                 8,
#                 9,
#                 15,
#                 14,
#                 3,
#                 3,
#                 3,
#                 1,
#                 1,
#                 2,
#                 5,
#                 5,
#                 5,
#                 2,
#                 1,
#                 2,
#                 23,
#                 6,
#                 4,
#                 3,
#                 4,
#                 3,
#                 4,
#                 7,
#                 1,
#                 9,
#                 2,
#                 2,
#                 4,
#                 10,
#                 8,
#                 7,
#                 11,
#                 18,
#                 3,
#                 2,
#                 1,
#                 4,
#                 6,
#                 9,
#                 19,
#                 13,
#                 33,
#                 16,
#                 33,
#                 44,
#                 53,
#                 37,
#                 61,
#                 34,
#                 56,
#                 29,
#                 32,
#                 47,
#                 22,
#                 26,
#                 34,
#                 51,
#                 47,
#                 17,
#                 42,
#                 30,
#                 32,
#                 64,
#                 53,
#                 39,
#                 41,
#                 16,
#                 14,
#                 9,
#                 6,
#                 17,
#                 6,
#                 7,
#                 7,
#                 14,
#                 28,
#                 12,
#                 5,
#                 14,
#                 6
#             ],
#             "stack": "stack1",
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         },
#         {
#             "type": "bar",
#             "name": "Pass",
#             "data": [
#                 1,
#                 1,
#                 3,
#                 2,
#                 2,
#                 6,
#                 3,
#                 4,
#                 1,
#                 1,
#                 2,
#                 9,
#                 5,
#                 19,
#                 23,
#                 3,
#                 1,
#                 37,
#                 5,
#                 9,
#                 2,
#                 1,
#                 2,
#                 8,
#                 2,
#                 10,
#                 2,
#                 2,
#                 5,
#                 6,
#                 14,
#                 9,
#                 17,
#                 11,
#                 2,
#                 5,
#                 2,
#                 3,
#                 2,
#                 2,
#                 1,
#                 2,
#                 2,
#                 7,
#                 2,
#                 1,
#                 3,
#                 3,
#                 3,
#                 2,
#                 2,
#                 2,
#                 7,
#                 3,
#                 5,
#                 4,
#                 2,
#                 4,
#                 4,
#                 1,
#                 3,
#                 8,
#                 7,
#                 15,
#                 7,
#                 1,
#                 3,
#                 5,
#                 3,
#                 5,
#                 6,
#                 5,
#                 21,
#                 20,
#                 21,
#                 34,
#                 66,
#                 51,
#                 62,
#                 17,
#                 48,
#                 64,
#                 69,
#                 60,
#                 33,
#                 56,
#                 43,
#                 68,
#                 95,
#                 56,

# %%
data = train.groupby(['Parameter6','Quality_label'],as_index=False)['Parameter1'].count().rename(
    columns={'Parameter1':'count'})

c = parameter_label(data, 'Parameter6', 350)
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="4305eb456ce543959d1ce56f9785c849" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_4305eb456ce543959d1ce56f9785c849 = echarts.init(
#                     document.getElementById('4305eb456ce543959d1ce56f9785c849'), 'white', {renderer: 'canvas'});
#                 var option_4305eb456ce543959d1ce56f9785c849 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "name": "Excellent",
#             "data": [
#                 1,
#                 1,
#                 1,
#                 1,
#                 1,
#                 1,
#                 6,
#                 2,
#                 1,
#                 4,
#                 7,
#                 11,
#                 8,
#                 5,
#                 4,
#                 9,
#                 15,
#                 6,
#                 3,
#                 2,
#                 4,
#                 3,
#                 3,
#                 5,
#                 5,
#                 7,
#                 3,
#                 7,
#                 2,
#                 3,
#                 1,
#                 6,
#                 4,
#                 1,
#                 4,
#                 7,
#                 8,
#                 11,
#                 14,
#                 15,
#                 15,
#                 16,
#                 21,
#                 42,
#                 21,
#                 54,
#                 58,
#                 78,
#                 80,
#                 65,
#                 53,
#                 61,
#                 55,
#                 63,
#                 31,
#                 27,
#                 64,
#                 21,
#                 14,
#                 15,
#                 18,
#                 18,
#                 12,
#                 3
#             ],
#             "stack": "stack1",
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         },
#         {
#             "type": "bar",
#             "name": "Good",
#             "data": [
#                 1,
#                 7,
#                 2,
#                 3,
#                 2,
#                 4,
#                 6,
#                 2,
#                 4,
#                 2,
#                 1,
#                 1,
#                 5,
#                 13,
#                 1,
#                 2,
#                 9,
#                 9,
#                 15,
#                 19,
#                 13,
#                 19,
#                 41,
#                 10,
#                 2,
#                 6,
#                 13,
#                 4,
#                 7,
#                 24,
#                 9,
#                 8,
#                 9,
#                 14,
#                 15,
#                 12,
#                 21,
#                 18,
#                 9,
#                 12,
#                 6,
#                 7,
#                 2,
#                 10,
#                 15,
#                 6,
#                 12,
#                 15,
#                 20,
#                 28,
#                 20,
#                 32,
#                 57,
#                 27,
#                 60,
#                 57,
#                 95,
#                 90,
#                 53,
#                 63,
#                 85,
#                 83,
#                 67,
#                 41,
#                 43,
#                 70,
#                 32,
#                 33,
#                 13,
#                 27,
#                 17,
#                 13,
#                 11
#             ],
#             "stack": "stack1",
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         },
#         {
#             "type": "bar",
#             "name": "Pass",
#             "data": [
#                 5,
#                 1,
#                 1,
#                 1,
#                 2,
#                 5,
#                 2,
#                 1,
#                 1,
#                 2,
#                 4,
#                 10,
#                 2,
#                 5,
#                 16,
#                 8,
#                 26,
#                 27,
#                 7,
#                 13,
#                 23,
#                 8,
#                 4,
#                 5,
#                 9,
#                 3,
#                 10,
#                 28,
#                 10,
#                 10,
#                 8,
#                 5,
#                 12,
#                 5,
#                 8,
#                 12,
#                 4,
#                 11,
#                 9,
#                 8,
#                 11,
#                 6,
#                 15,
#                 19,
#                 17,
#                 13,
#                 5,
#                 26,
#                 12,
#                 21,
#                 35,
#                 31,
#                 45,
#                 61,
#                 67,
#                 98,
#                 91,
#                 169,
#                 117,
#                 87,
#                 140,
#                 129,
#                 94,
#                 259,
#                 91,
#                 85,
#                 75,
#                 101,
#                 90,
#                 58,
#                 18
#             ],
#             "stack": "stack1",
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         },
#         {
#             "type": "bar",
#             "name": "Fail",
#             "data": [
#                 2,
#                 5,
#                 9,
#                 2,
#                 3,
#                 2,
#                 2,
#                 6,
#                 2,
#                 2,
#                 2,
#                 4,
#                 3,
#                 2,
#                 9,
#                 8,
#                 6,
#                 3,
#                 9,
#                 14,
#                 27,
#                 11,
#                 1,
#                 11,
#                 5,
#                 18,
#                 20,
#                 9,
#                 16,
#                 9,
#                 29,
#                 28,
#                 8,
#                 9,
#                 18,
#                 8,
#                 6,
#                 5,
#                 7,
#                 7,
#                 7,
#                 12,
#                 19,
#                 25,
#                 4,
#                 8,
#                 17,
#                 12,
#                 13,
#                 15,
#                 12,
#                 21,
#                 24,
#                 25,
#                 32,
#                 28,

# %%
data = train.groupby(['Parameter7','Quality_label'],as_index=False)['Parameter1'].count().rename(
    columns={'Parameter1':'count'})

c = parameter_label(data, 'Parameter7', 2500)
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="c2c638d5a26c48088444a3ae6090c416" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_c2c638d5a26c48088444a3ae6090c416 = echarts.init(
#                     document.getElementById('c2c638d5a26c48088444a3ae6090c416'), 'white', {renderer: 'canvas'});
#                 var option_c2c638d5a26c48088444a3ae6090c416 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "name": "Excellent",
#             "data": [
#                 4,
#                 114,
#                 253,
#                 457,
#                 154,
#                 13,
#                 56,
#                 10,
#                 4,
#                 42
#             ],
#             "stack": "stack1",
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         },
#         {
#             "type": "bar",
#             "name": "Good",
#             "data": [
#                 1,
#                 5,
#                 196,
#                 440,
#                 506,
#                 133,
#                 9,
#                 24,
#                 129,
#                 18,
#                 3,
#                 115,
#                 5
#             ],
#             "stack": "stack1",
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         },
#         {
#             "type": "bar",
#             "name": "Pass",
#             "data": [
#                 1,
#                 16,
#                 93,
#                 1080,
#                 363,
#                 555,
#                 8,
#                 25,
#                 111,
#                 31,
#                 11,
#                 120,
#                 2,
#                 1
#             ],
#             "stack": "stack1",
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         },
#         {
#             "type": "bar",
#             "name": "Fail",
#             "data": [
#                 16,
#                 92,
#                 231,
#                 207,
#                 45,
#                 12,
#                 41,
#                 110,
#                 31,
#                 21,
#                 73,
#                 1,
#                 12
#             ],
#             "stack": "stack1",
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "Excellent",
#                 "Good",
#                 "Pass",
#                 "Fail"
#             ],
#             "selected": {
#                 "Excellent": true,
#                 "Good": true,
#                 "Pass": true,
#                 "Fail": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 0.00062,
#                 0.00246,
#                 0.03848,
#                 0.15206,
#                 0.60083,
#                 2.37403,
#                 9.38047,
#                 37.06487,
#                 146.45366,
#                 578.67929,
#                 1150.28855,
#                 2286.52341,
#                 9034.69232,
#                 35698.59155
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "max": 2500,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "text": "Parameter7",
#             "subtext": "https://lambda-xmu.club"
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "horizontal",
#         "itemSize": 15,
#         "itemGap": 10,
#         "left": "80%",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "save as image",
#                 "type": "png"
#             },
#             "restore": {
#                 "show": true,
#                 "title": "restore"
#             },
#             "dataView": {
#                 "show": true,
#                 "title": "data view",
#                 "readOnly": false
#             },
#             "dataZoom": {
#                 "show": true,
#                 "title": {
#                     "zoom": "data zoom",
#                     "back": "data zoom restore"
#                 }
#             }
#         }
#     }
# };
#                 chart_c2c638d5a26c48088444a3ae6090c416.setOption(option_c2c638d5a26c48088444a3ae6090c416);
#         });
#     </script>

# %%
data = train.groupby(['Parameter8','Quality_label'],as_index=False)['Parameter1'].count().rename(
    columns={'Parameter1':'count'})

c = parameter_label(data, 'Parameter8', 2100)
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="172ff28470cd4266807829b197bea5f2" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_172ff28470cd4266807829b197bea5f2 = echarts.init(
#                     document.getElementById('172ff28470cd4266807829b197bea5f2'), 'white', {renderer: 'canvas'});
#                 var option_172ff28470cd4266807829b197bea5f2 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "name": "Excellent",
#             "data": [
#                 1,
#                 288,
#                 4,
#                 1,
#                 8,
#                 117,
#                 1,
#                 37,
#                 5,
#                 143,
#                 488,
#                 9,
#                 2,
#                 2,
#                 1
#             ],
#             "stack": "stack1",
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         },
#         {
#             "type": "bar",
#             "name": "Good",
#             "data": [
#                 558,
#                 3,
#                 6,
#                 44,
#                 1,
#                 9,
#                 158,
#                 1,
#                 64,
#                 12,
#                 118,
#                 597,
#                 4,
#                 2,
#                 3,
#                 4
#             ],
#             "stack": "stack1",
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         },
#         {
#             "type": "bar",
#             "name": "Pass",
#             "data": [
#                 6,
#                 1279,
#                 11,
#                 5,
#                 53,
#                 1,
#                 1,
#                 3,
#                 74,
#                 3,
#                 63,
#                 7,
#                 465,
#                 339,
#                 55,
#                 7,
#                 8,
#                 1,
#                 35,
#                 1
#             ],
#             "stack": "stack1",
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         },
#         {
#             "type": "bar",
#             "name": "Fail",
#             "data": [
#                 1,
#                 379,
#                 20,
#                 17,
#                 58,
#                 4,
#                 7,
#                 1,
#                 89,
#                 27,
#                 6,
#                 32,
#                 228,
#                 2,
#                 13,
#                 1,
#                 1,
#                 1,
#                 4,
#                 1
#             ],
#             "stack": "stack1",
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "Excellent",
#                 "Good",
#                 "Pass",
#                 "Fail"
#             ],
#             "selected": {
#                 "Excellent": true,
#                 "Good": true,
#                 "Pass": true,
#                 "Fail": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 0.0237,
#                 0.03541,
#                 0.0529,
#                 0.07903,
#                 0.11808,
#                 0.17641,
#                 0.26356,
#                 0.39377,
#                 1.31314,
#                 2.93108,
#                 4.37911,
#                 6.5425,
#                 9.77467,
#                 14.6036,
#                 17.85002,
#                 21.81814,
#                 72.75978,
#                 162.40792,
#                 362.51253,
#                 541.60283,
#                 1208.91769,
#                 8998.83421,
#                 20086.39775
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "max": 2100,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "text": "Parameter8",
#             "subtext": "https://lambda-xmu.club"
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "horizontal",
#         "itemSize": 15,
#         "itemGap": 10,
#         "left": "80%",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "save as image",
#                 "type": "png"
#             },
#             "restore": {
#                 "show": true,
#                 "title": "restore"
#             },
#             "dataView": {
#                 "show": true,
#                 "title": "data view",
#                 "readOnly": false
#             },
#             "dataZoom": {
#                 "show": true,
#                 "title": {
#                     "zoom": "data zoom",
#                     "back": "data zoom rest

# %%
data = train.groupby(['Parameter9','Quality_label'],as_index=False)['Parameter1'].count().rename(
    columns={'Parameter1':'count'})

c = parameter_label(data, 'Parameter9', 3000)
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="87af6d89849543d680e9997707dd5498" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_87af6d89849543d680e9997707dd5498 = echarts.init(
#                     document.getElementById('87af6d89849543d680e9997707dd5498'), 'white', {renderer: 'canvas'});
#                 var option_87af6d89849543d680e9997707dd5498 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "name": "Excellent",
#             "data": [
#                 35,
#                 22,
#                 135,
#                 389,
#                 49,
#                 386,
#                 3,
#                 32,
#                 33,
#                 23
#             ],
#             "stack": "stack1",
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         },
#         {
#             "type": "bar",
#             "name": "Good",
#             "data": [
#                 33,
#                 87,
#                 174,
#                 641,
#                 52,
#                 405,
#                 12,
#                 70,
#                 40,
#                 69,
#                 1
#             ],
#             "stack": "stack1",
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         },
#         {
#             "type": "bar",
#             "name": "Pass",
#             "data": [
#                 56,
#                 33,
#                 472,
#                 1428,
#                 30,
#                 249,
#                 7,
#                 32,
#                 23,
#                 84,
#                 1,
#                 1,
#                 1
#             ],
#             "stack": "stack1",
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         },
#         {
#             "type": "bar",
#             "name": "Fail",
#             "data": [
#                 7,
#                 49,
#                 75,
#                 375,
#                 22,
#                 140,
#                 27,
#                 30,
#                 38,
#                 126,
#                 1,
#                 1,
#                 1
#             ],
#             "stack": "stack1",
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "Excellent",
#                 "Good",
#                 "Pass",
#                 "Fail"
#             ],
#             "selected": {
#                 "Excellent": true,
#                 "Good": true,
#                 "Pass": true,
#                 "Fail": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 0.0004,
#                 0.00453,
#                 0.05185,
#                 0.59308,
#                 2.00585,
#                 6.78397,
#                 22.94397,
#                 77.59849,
#                 262.44484,
#                 887.61126,
#                 4887.44047,
#                 10152.95222,
#                 16529.74869,
#                 116134.66829,
#                 1328407.82475,
#                 173808298.30161
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "max": 3000,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "text": "Parameter9",
#             "subtext": "https://lambda-xmu.club"
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "horizontal",
#         "itemSize": 15,
#         "itemGap": 10,
#         "left": "80%",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "save as image",
#                 "type": "png"
#             },
#             "restore": {
#                 "show": true,
#                 "title": "restore"
#             },
#             "dataView": {
#                 "show": true,
#                 "title": "data view",
#                 "readOnly": false
#             },
#             "dataZoom": {
#                 "show": true,
#                 "title": {
#                     "zoom": "data zoom",
#                     "back": "data zoom restore"
#                 }
#             }
#         }
#     }
# };
#                 chart_87af6d89849543d680e9997707dd5498.setOption(option_87af6d89849543d680e9997707dd5498);
#         });
#     </script>

# %%
data = train.groupby(['Parameter10','Quality_label'],as_index=False)['Parameter1'].count().rename(
    columns={'Parameter1':'count'})

c = parameter_label(data, 'Parameter10', 500)
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="a76724f48e714607a2b837c0be3db3fe" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_a76724f48e714607a2b837c0be3db3fe = echarts.init(
#                     document.getElementById('a76724f48e714607a2b837c0be3db3fe'), 'white', {renderer: 'canvas'});
#                 var option_a76724f48e714607a2b837c0be3db3fe = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "name": "Excellent",
#             "data": [
#                 3,
#                 1,
#                 1,
#                 5,
#                 4,
#                 17,
#                 25,
#                 30,
#                 103,
#                 82,
#                 58,
#                 87,
#                 119,
#                 33,
#                 77,
#                 49,
#                 30,
#                 30,
#                 19,
#                 18,
#                 21,
#                 27,
#                 12,
#                 18,
#                 16,
#                 16,
#                 24,
#                 19,
#                 31,
#                 12,
#                 21,
#                 9,
#                 30,
#                 10,
#                 21,
#                 11,
#                 18
#             ],
#             "stack": "stack1",
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         },
#         {
#             "type": "bar",
#             "name": "Good",
#             "data": [
#                 1,
#                 3,
#                 23,
#                 25,
#                 4,
#                 11,
#                 31,
#                 19,
#                 54,
#                 41,
#                 52,
#                 154,
#                 96,
#                 83,
#                 72,
#                 64,
#                 46,
#                 60,
#                 43,
#                 29,
#                 43,
#                 44,
#                 21,
#                 21,
#                 35,
#                 17,
#                 23,
#                 31,
#                 38,
#                 32,
#                 44,
#                 52,
#                 27,
#                 30,
#                 27,
#                 47,
#                 24,
#                 26,
#                 24,
#                 67
#             ],
#             "stack": "stack1",
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         },
#         {
#             "type": "bar",
#             "name": "Pass",
#             "data": [
#                 5,
#                 7,
#                 8,
#                 9,
#                 8,
#                 19,
#                 12,
#                 42,
#                 76,
#                 73,
#                 78,
#                 98,
#                 170,
#                 67,
#                 126,
#                 83,
#                 116,
#                 71,
#                 108,
#                 89,
#                 108,
#                 121,
#                 48,
#                 126,
#                 60,
#                 141,
#                 50,
#                 131,
#                 136,
#                 19,
#                 49,
#                 16,
#                 44,
#                 23,
#                 11,
#                 22,
#                 47
#             ],
#             "stack": "stack1",
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         },
#         {
#             "type": "bar",
#             "name": "Fail",
#             "data": [
#                 7,
#                 1,
#                 5,
#                 23,
#                 23,
#                 13,
#                 19,
#                 18,
#                 49,
#                 40,
#                 32,
#                 32,
#                 44,
#                 17,
#                 9,
#                 21,
#                 15,
#                 15,
#                 29,
#                 25,
#                 18,
#                 27,
#                 10,
#                 17,
#                 11,
#                 34,
#                 17,
#                 17,
#                 22,
#                 33,
#                 29,
#                 35,
#                 32,
#                 19,
#                 13,
#                 24,
#                 20,
#                 8,
#                 12,
#                 9,
#                 48
#             ],
#             "stack": "stack1",
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "Excellent",
#                 "Good",
#                 "Pass",
#                 "Fail"
#             ],
#             "selected": {
#                 "Excellent": true,
#                 "Good": true,
#                 "Pass": true,
#                 "Fail": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 0.00102,
#                 0.00142,
#                 0.00197,
#                 0.00274,
#                 0.00381,
#                 0.00529,
#                 0.00734,
#                 0.01019,
#                 0.01415,
#                 0.01965,
#                 0.02729,
#                 0.0379,
#                 0.05263,
#                 0.07308,
